# %%
import binary_classification
# Out:
# Predictive performance of the ML methods for the randomly selected test sets in each iteration
# Confusion matrix for the last iteration of the randomly selected test sets.
# Comparison of the average predictive performances of the two methods:
# 1: Randomly selecting test set in each of the n iterations.
#    AVG10 means average of 10 iterations.
# 2: Performing k-fold cross-validation.
#    CV5 means 5-fold cross-validation.
